# %%
import os

os.chdir("/home/vadim/Документы/Quantum/q-e-qe-7.0")

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
data = [
    (40, 2, -39.55143823),
    (40, 4, -39.48102141),
    (40, 6, -39.50789015),
    (40, 8, -39.50246624),
    (40, 10, -39.50159016),
    (50, 2, -39.55145323),
    (50, 4, -39.48103621),
    (50, 6, -39.50790484),
    (50, 8, -39.50248115),
    (50, 10, -39.50160508),
    (60, 2, -39.55145892), 
    (60, 4, -39.48104207),
    (60, 6, -39.50791065),
    (60, 8, -39.50248706),
    (60, 10, -39.50161102),
    (70, 2, -39.55146324),
    (70, 4, -39.48104640),
    (70, 6, -39.50791500),
    (70, 8, -39.50249136),
    (70, 10, -39.50161534),
    (80, 2, -39.55146383),
    (80, 4, -39.48104704), 
    (80, 6, -39.50791563),
    (80, 8, -39.50249198),
    (80, 10, -39.50161597)
]

# %%
data = np.array([list(val) for val in data])

# %%
data = np.asarray(data)

# %%
fig = plt.figure(figsize=(10,8))

ax = fig.add_subplot(111, projection='3d')
ax.scatter(data[:, 0], data[:, 1], data[:, 2])
ax.set_zlim(-39.57, -39.47)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
(-39.24176547 + 39.50161102)*13.6056980659
# Out:
# 3.5353800970677414

# %% [markdown]
# ## HW2

# %%
# %matplotlib notebook

import re
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
import os

os.chdir("/home/vadim/Документы/Quantum/q-e-qe-7.0")

# %%
A = 4.0478 * 0.4991 / 0.5
volumes = []
energies = []
for i in tqdm(np.arange(-5, 5, 0.5)):
    if i == 0:
        continue
    with open(r"HW/al2.in", 'w') as f:
        text = '''
&control
    calculation = 'scf'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 2
    A = {}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
&cell
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
         '''.format(A * (1 + i/100))
        f.write(text)
        f.close()
        res = !mpirun -n 4 bin/pw.x -in HW/al2.in
        res = ''.join(res)
        #print(res)
        volumes.append((A * (1 + i/100)) ** 3)
        energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
        energy = float(re.findall(r"-[\d\.]+", energy)[0])
        energies.append(energy)
# Out:
# 100%|██████████| 20/20 [00:41<00:00,  2.23s/it]

# %%
def new_eos(v, e0, b0, v0, d):
    temp = ((v0/v)**(2/3) - 1)
    val = e0 + 9*b0*v0/16*(temp ** 3 * d + 
                           temp ** 2 * (6 - 4*(v0/v)**(2/3)))
    return val

# %%
bounds=(
    (-50, -np.inf, 63, 1),
    (-30, np.inf, 67, 1000)
)
fit, cov = curve_fit(new_eos, volumes, energies, bounds=bounds,
                    method='trf')

# %%
fit
# Out:
# array([-3.95016203e+01,  8.51701798e-03,  6.59415176e+01,  4.86841205e+00])

# %%
fig = plt.figure()
ax = fig.gca()
x = np.linspace(50, 100.0, 200)
ax.set_xlabel("Volume")
ax.set_ylabel("Energy")
ax.plot(x, new_eos(x, *fit))
ax.scatter(volumes, energies)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig = plt.figure()
ax = fig.gca()
x = np.linspace(20, 800.0, 200)
ax.set_xlabel("Volume")
ax.set_ylabel("Energy")
ax.plot(x, new_eos(x, *fit))
ax.scatter(volumes, energies)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
{
    'E0': -3.95016203e+01,
    'B0': 8.51695766e-03,
    'V0': 6.59413315e+01,
    'B\'': 4.87018638
}
# Out:
# {'E0': -39.5016203, 'B0': 0.00851695766, 'V0': 65.9413315, "B'": 4.87018638}

# %% [markdown]
# ## Bulk

# %%
volumes = []
energies = []
for i in tqdm(np.arange(-1, 2)):
    with open(r"HW/al2.in", 'w') as f:
        val = 0.500 * (1 + i / 100)
        text = f'''
&control
    calculation = 'scf'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.00 {val} {val}
    {val} 0.00 {val}
    {val} {val} 0.00
         '''
        f.write(text)
        f.close()
        res = !mpirun -n 4 bin/pw.x -in HW/al2.in
        res = ''.join(res)
        energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
        energy = float(re.findall(r"-[\d\.]+", energy)[0])
        energies.append(energy)
        print(i, " : ", energy)
# Out:
#  33%|███▎      | 1/3 [00:02<00:04,  2.13s/it]
# -1  :  -39.50136371
#  67%|██████▋   | 2/3 [00:04<00:02,  2.16s/it]
# 0  :  -39.50162021
# 100%|██████████| 3/3 [00:06<00:00,  2.21s/it]
# 1  :  -39.50137152

# %%
volume = A ** 3
bulk = (energies[0] + energies[2] - 2*energies[1]) / (0.01) ** 2
bulk = bulk / (9 * volume)
bulk * 160.2 * 13.6056 * 4
# Out:
# 74.18952711079233

# %% [markdown]
# ## c11

# %%
volumes = []
energies = []
for i in tqdm(np.arange(-1, 2)):
    with open(r"HW/al2.in", 'w') as f:
        val = 0.500 * (1 + i / 100)
        print(val)
        text = f'''
&control
    calculation = 'scf'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.00 0.50 0.50
    {val} 0.00 0.50
    {val} 0.50 0.00
         '''
        f.write(text)
        f.close()
        res = !mpirun -n 4 bin/pw.x -in HW/al2.in
        res = ''.join(res)
        energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
        energy = float(re.findall(r"-[\d\.]+", energy)[0])
        energies.append(energy)
        print(i, " : ", energy)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0.495
#  33%|███▎      | 1/3 [00:03<00:06,  3.32s/it]
# -1  :  -39.50161297
# 0.5
#  67%|██████▋   | 2/3 [00:05<00:02,  2.99s/it]
# 0  :  -39.50162021
# 0.505
# 100%|██████████| 3/3 [00:08<00:00,  3.12s/it]
# 1  :  -39.5016072

# %%
volume = A ** 3
c11 = (energies[0] + energies[2] - 2*energies[1]) / (0.01) ** 2
c11 = c11 / (volume)
c11 * 160.2 * 13.6056 * 4
# Out:
# 26.76426952196722

# %%
E0 = energies[1]

# %% [markdown]
# ## c22

# %%
volumes = []
energies = []
for i in tqdm(np.arange(-1, 2)):
    with open(r"HW/al2.in", 'w') as f:
        val = 0.500 * (1 + i / 100)
        text = f'''
&control
    calculation = 'scf'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.00 {val} 0.50
    0.50 0.00 0.50
    0.50 {val} 0.00
         '''
        f.write(text)
        f.close()
        res = !mpirun -n 4 bin/pw.x -in HW/al2.in
        res = ''.join(res)
        volumes.append((A * (1 + i/100)) ** 3)
        energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
        energy = float(re.findall(r"-[\d\.]+", energy)[0])
        energies.append(energy)
        print(i, " : ", energy)
# Out:
#  33%|███▎      | 1/3 [00:03<00:07,  3.68s/it]
# -1  :  -39.50161297
#  67%|██████▋   | 2/3 [00:05<00:03,  3.25s/it]
# 0  :  -39.50162021
# 100%|██████████| 3/3 [00:09<00:00,  3.29s/it]
# 1  :  -39.5016072

# %%
volume = A ** 3
c22 = (energies[0] + energies[2] - 2*energies[1]) / (0.01) ** 2
c22 = c22 / (volume)
c22 * 160.2 * 13.6056 * 4
# Out:
# 26.76426952196722

# %% [markdown]
# ## c33

# %%
volumes = []
energies = []
for i in tqdm(np.arange(-1, 2)):
    with open(r"HW/al2.in", 'w') as f:
        val = 0.500 * (1 + i / 100)
        print(val)
        text = f'''
&control
    calculation = 'scf'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.00 0.5 {val}
    0.5 0.00 {val}
    0.5 0.5 0.00
         '''
        f.write(text)
        f.close()
        res = !mpirun -n 4 bin/pw.x -in HW/al2.in
        res = ''.join(res)
        volumes.append((A * (1 + i/100)) ** 3)
        energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
        energy = float(re.findall(r"-[\d\.]+", energy)[0])
        energies.append(energy)
        print(i, " : ", energy)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0.495
#  33%|███▎      | 1/3 [00:03<00:06,  3.38s/it]
# -1  :  -39.50161297
# 0.5
#  67%|██████▋   | 2/3 [00:05<00:03,  3.07s/it]
# 0  :  -39.50162021
# 0.505
# 100%|██████████| 3/3 [00:09<00:00,  3.18s/it]
# 1  :  -39.5016072

# %%
volume = A ** 3
c33 = (energies[0] + energies[2] - 2*energies[1]) / (0.01) ** 2
c33 = c33 / (volume)
c33 * 160.2 * 13.6056 * 4
# Out:
# 26.76426952196722

# %% [markdown]
# ## c44

# %%
volumes = []
energies = []
with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.4950165011000856 0.4950165011000856
    0.5000166677778642 -0.005000166677778642 0.5000166677778642
    0.5000166677778642 0.5000166677778642 -0.005000166677778642
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)


with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
$ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.5050168344556429 0.5050168344556429
    0.5000166677778642 0.005000166677778642 0.5000166677778642
    0.5000166677778642 0.5000166677778642 0.005000166677778642
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)
# Out:
# 1  :  -39.50160432
# 1  :  -39.50160431

# %%
volume = A ** 3
c44 = (energies[1] + energies[0] - 2*E0) / (0.01) ** 2
c44 = c44 / (4 * volume) 
c44 * 160.2 * 13.6056 * 4
# Out:
# 10.504149729485334

# %% [markdown]
# ## c55

# %%
mat = np.asarray([
    [0, 0.5, 0.5],
    [0.5, 0, 0.5],
    [0.5, 0.5, 0]
])

# %%
val = 1 / (1 - 0.01**2) ** (1/3)

# %%
mat @ np.asarray([
    [val, 0, -val * 0.01],
    [0, val, 0],
    [-val * 0.01, 0, val]
])
# Out:
# array([[-0.00500017,  0.50001667,  0.50001667],
#        [ 0.4950165 ,  0.        ,  0.4950165 ],
#        [ 0.50001667,  0.50001667, -0.00500017]])

# %%
volumes = []
energies = []
with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.005000166677778642 0.5000166677778642 0.5000166677778642
    0.5050168344556429 0.0 0.5050168344556429
    0.5000166677778642 0.5000166677778642 0.005000166677778642
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)


with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
$ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    -0.005000166677778642 0.5000166677778642 0.5000166677778642
    0.4950165011000856 0 0.4950165011000856
    0.5000166677778642 0.5000166677778642 -0.005000166677778642
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)
# Out:
# 1  :  -39.50160431
# 1  :  -39.50160431

# %%
volume = A ** 3
c55 = (energies[1] + energies[0] - 2*E0) / (0.01) ** 2
c55 = c55 / (4 * volume)
c55 * 160.2 * 13.6056 * 4
# Out:
# 10.507453958215176

# %% [markdown]
# ## c66

# %%
mat @ np.asarray([
    [val, -val*0.01, 0],
    [-val*0.01, val, 0],
    [0, 0, val]
])
# Out:
# array([[-0.00500017,  0.50001667,  0.50001667],
#        [ 0.50001667, -0.00500017,  0.50001667],
#        [ 0.4950165 ,  0.4950165 ,  0.        ]])

# %%
volumes = []
energies = []
with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.005000166677778642 0.5000166677778642 0.5000166677778642
    0.5000166677778642 0.005000166677778642 0.5000166677778642
    0.5050168344556429 0.5050168344556429 0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)


with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
$ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    -0.005000166677778642 0.5000166677778642 0.5000166677778642
    0.5000166677778642 -0.005000166677778642 0.5000166677778642
    0.4950165011000856 0.4950165011000856 0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)
# Out:
# 1  :  -39.50160431
# 1  :  -39.50160431

# %%
volume = A ** 3
c66 = (energies[1] + energies[0] - 2*E0) / (0.01) ** 2
c66 = c66 / (4 * volume)
c66 * 160.2 * 13.6056 * 4
# Out:
# 10.507453958215176

# %% [markdown]
# ## c12

# %%
val = 1 / (1 - 0.01**2) ** (1/3)

# %%
res = mat @ np.asarray([
    [(1 - 0.01)*val, 0, 0],
    [0, (1 + 0.01)*val, 0],
    [0, 0, val]
])

# %%
res
# Out:
# array([[0.        , 0.50501683, 0.50001667],
#        [0.4950165 , 0.        , 0.50001667],
#        [0.4950165 , 0.50501683, 0.        ]])

# %%
0.4950165011000856, 0.5000166677778642, 0.5050168344556429
# Out:
# (0.4950165011000856, 0.5000166677778642, 0.5050168344556429)

# %%
volumes = []
energies = []
with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.4950165011000856 0.5000166677778642
    0.5050168344556429 0.0 0.5000166677778642
    0.5050168344556429 0.4950165011000856 0.0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)


with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
$ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.5050168344556429 0.5000166677778642
    0.4950165011000856 0.0 0.5000166677778642
    0.4950165011000856 0.5050168344556429 0.0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)
# Out:
# 1  :  -39.50168065
# 1  :  -39.50168065

# %%
c12 = (energies[1] + energies[0] - 2*E0) / (0.01) ** 2

# %%
c12 = (c11 + c22) * 2 - c12 / (2*volume)

# %%
c12 * 160.9 * 13.6 * 4
# Out:
# 187.67972427916285

# %% [markdown]
# ## c13

# %%
res = mat @ np.asarray([
    [(1 + 0.01)*val, 0, 0],
    [0, val, 0],
    [0, 0, (1 - 0.01) * val]
])

# %%
res
# Out:
# array([[0.        , 0.50001667, 0.4950165 ],
#        [0.50501683, 0.        , 0.4950165 ],
#        [0.50501683, 0.50001667, 0.        ]])

# %%
0.4950165011000856, 0.5000166677778642, 0.5050168344556429
# Out:
# (0.4950165011000856, 0.5000166677778642, 0.5050168344556429)

# %%
volumes = []
energies = []
with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.5000166677778642 0.5050168344556429
    0.4950165011000856 0.0 0.5050168344556429
    0.4950165011000856 0.5000166677778642 0.0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)


with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
$ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.5000166677778642 0.4950165011000856
    0.5050168344556429 0.0 0.4950165011000856
    0.5050168344556429 0.5000166677778642 0.0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)
# Out:
# 1  :  -39.50168065
# 1  :  -39.50168065

# %%
c13 = (energies[1] + energies[0] - 2*E0) / (0.01) ** 2

# %%
c13 = (c11 + c33) * 2 - c13 / (2*volume)

# %%
c13 * 160.9 * 13.6 * 4
# Out:
# 187.67972427916285

# %% [markdown]
# ## c23

# %%
res = mat @ np.asarray([
    [val, 0, 0],
    [0, (1 - 0.01)*val, 0],
    [0, 0, (1 + 0.01) * val]
])

# %%
res
# Out:
# array([[0.        , 0.4950165 , 0.50501683],
#        [0.50001667, 0.        , 0.50501683],
#        [0.50001667, 0.4950165 , 0.        ]])

# %%
0.4950165011000856, 0.5000166677778642, 0.5050168344556429
# Out:
# (0.4950165011000856, 0.5000166677778642, 0.5050168344556429)

# %%
volumes = []
energies = []
with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
&ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.5050168344556429 0.4950165011000856
    0.5000166677778642 0.0 0.4950165011000856
    0.5000166677778642 0.5050168344556429 0.0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)


with open(r"HW/al2.in", 'w') as f:
    text = f'''
&control
    calculation = 'relax'
    prefix = 'cubic'
    pseudo_dir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/sssp'
    outdir = '/home/vadim/Документы/Quantum/q-e-qe-7.0/out'
/
&system
    ibrav = 0
    A = {A}
    nat = 1
    ntyp = 1
    ecutwfc = 60
    ecutrho = 480
    occupations = 'smearing'
    smearing = 'cold'
    degauss = 0.02
/
&electrons
    conv_thr=1.d-8
/
$ions
/
ATOMIC_SPECIES
    Al 26.981 Al.pbe-n-kjpaw_psl.1.0.0.UPF
ATOMIC_POSITIONS crystal
    Al 0.0 0.0 0.0
K_POINTS automatic
    10 10 10 0 0 0
CELL_PARAMETERS alat
    0.0 0.4950165011000856 0.5050168344556429
    0.5000166677778642 0.0 0.5050168344556429
    0.5000166677778642 0.4950165011000856 0.0
         '''
    f.write(text)
    f.close()
    res = !mpirun -n 4 bin/pw.x -in HW/al2.in
    res = ''.join(res)
    volumes.append((A * (1 + i/100)) ** 3)
    energy = re.findall(r"!\s+total energy\s+=\s+-[\d\.]+", res)[0]
    energy = float(re.findall(r"-[\d\.]+", energy)[0])
    energies.append(energy)
    print(i, " : ", energy)
# Out:
# 1  :  -39.50168065
# 1  :  -39.50168065

# %%
c23 = (energies[1] + energies[0] - 2*E0) / (0.01) ** 2

# %%
c23 = (c22 + c33) * 2 - c23 / (2*volume)

# %%
c13 * 160.9 * 13.6 * 4
# Out:
# 187.67972427916285
